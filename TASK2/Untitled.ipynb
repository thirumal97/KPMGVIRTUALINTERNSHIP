# %%
import pandas as pd
import numpy as np
import openpyxl
from pandas import ExcelWriter
from datetime import datetime
from datetime import date

# %%
trans_df = pd.read_excel(r"C:\Users\Thirumal\Documents\KPMGvirtualInternship\Task1\New\Updatedtransactions.xlsx", sheet_name= "Updatedtransactions")
newcustomerlist_df=pd.read_excel(r'C:\Users\Thirumal\Documents\KPMGvirtualInternship\Task1\New\UpdatedNewCustomerList.xlsx', sheet_name='UpdatedNewCustomerList', index = False)
customeraddress_df=pd.read_excel(r'C:\Users\Thirumal\Documents\KPMGvirtualInternship\Task1\New\UpdatedCustomerAddress.xlsx', sheet_name='UpdatedCustomerAddress', index = False)
customerdemographic_df=pd.read_excel(r'C:\Users\Thirumal\Documents\KPMGvirtualInternship\Task1\New\UpdatedCustomerDemographic.xlsx', sheet_name='UpdatedCustomerDemographic', index = False)

# %%
trans_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   transaction_id           20000 non-null  int64
#  1   product_id               20000 non-null  int64
#  2   customer_id              20000 non-null  int64
#  3   transaction_date         20000 non-null  datetime64[ns]
#  4   online_order             19640 non-null  float64
#  5   order_status             20000 non-null  object
#  6   brand                    19803 non-null  object
#  7   product_line             19803 non-null  object
#  8   product_class            19803 non-null  object
#  9   product_size             19803 non-null  object
#  10  list_price               20000 non-null  float64
#  11  standard_cost            19803 non-null  float64
#  12  product_first_sold_date  19803 non-null  float64
# ...

# %%
trans_df['product_first_sold_date']= pd.to_datetime(trans_df['product_first_sold_date'], unit = 's')

# %%
trans_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   transaction_id           20000 non-null  int64
#  1   product_id               20000 non-null  int64
#  2   customer_id              20000 non-null  int64
#  3   transaction_date         20000 non-null  datetime64[ns]
#  4   online_order             19640 non-null  float64
#  5   order_status             20000 non-null  object
#  6   brand                    19803 non-null  object
#  7   product_line             19803 non-null  object
#  8   product_class            19803 non-null  object
#  9   product_size             19803 non-null  object
#  10  list_price               20000 non-null  float64
#  11  standard_cost            19803 non-null  float64
#  12  product_first_sold_date  19803 non-null  datetime64[ns]
# ...

# %%
newcustomerlist_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 23 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   first_name                           1000 non-null   object
#  1   last_name                            971 non-null    object
#  2   gender                               1000 non-null   object
#  3   past_3_years_bike_related_purchases  1000 non-null   int64
#  4   DOB                                  983 non-null    datetime64[ns]
#  5   job_title                            894 non-null    object
#  6   job_industry_category                835 non-null    object
#  7   wealth_segment                       1000 non-null   object
#  8   deceased_indicator                   1000 non-null   object
#  9   owns_car                             1000 non-null   object
#  10  tenure                               1000 non-null   int64
# ...

# %%
newcustomerlist_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 23 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   first_name                           1000 non-null   object
#  1   last_name                            971 non-null    object
#  2   gender                               1000 non-null   object
#  3   past_3_years_bike_related_purchases  1000 non-null   int64
#  4   DOB                                  983 non-null    datetime64[ns]
#  5   job_title                            894 non-null    object
#  6   job_industry_category                835 non-null    object
#  7   wealth_segment                       1000 non-null   object
#  8   deceased_indicator                   1000 non-null   object
#  9   owns_car                             1000 non-null   object
#  10  tenure                               1000 non-null   int64
# ...

# %%
newcustomerlist_df = newcustomerlist_df.drop(['Unnamed: 16','Unnamed: 17','Unnamed: 18','Unnamed: 19','Unnamed: 20'], axis=1)

# %%
newcustomerlist_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 18 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   first_name                           1000 non-null   object
#  1   last_name                            971 non-null    object
#  2   gender                               1000 non-null   object
#  3   past_3_years_bike_related_purchases  1000 non-null   int64
#  4   DOB                                  983 non-null    datetime64[ns]
#  5   job_title                            894 non-null    object
#  6   job_industry_category                835 non-null    object
#  7   wealth_segment                       1000 non-null   object
#  8   deceased_indicator                   1000 non-null   object
#  9   owns_car                             1000 non-null   object
#  10  tenure                               1000 non-null   int64
# ...

# %%
newcustomerlist_df = newcustomerlist_df.astype({'tenure': float})
newcustomerlist_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 18 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   first_name                           1000 non-null   object
#  1   last_name                            971 non-null    object
#  2   gender                               1000 non-null   object
#  3   past_3_years_bike_related_purchases  1000 non-null   int64
#  4   DOB                                  983 non-null    datetime64[ns]
#  5   job_title                            894 non-null    object
#  6   job_industry_category                835 non-null    object
#  7   wealth_segment                       1000 non-null   object
#  8   deceased_indicator                   1000 non-null   object
#  9   owns_car                             1000 non-null   object
#  10  tenure                               1000 non-null   float64
# ...

# %%
newcustomerlist_df['DOB'] = newcustomerlist_df['DOB'].fillna(method = 'ffill')
newcustomerlist_df['job_title'] = newcustomerlist_df['job_title'].fillna(method= 'ffill')
newcustomerlist_df['job_industry_category'] = newcustomerlist_df['job_industry_category'].fillna(method = 'ffill')

# %%
customeraddress_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   customer_id         3999 non-null   int64
#  1   address             3999 non-null   object
#  2   postcode            3999 non-null   int64
#  3   state               3999 non-null   object
#  4   country             3999 non-null   object
#  5   property_valuation  3999 non-null   int64
# dtypes: int64(3), object(3)
# memory usage: 187.6+ KB

# %%
customerdemographic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 12 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   customer_id                          4000 non-null   int64
#  1   first_name                           4000 non-null   object
#  2   last_name                            3875 non-null   object
#  3   gender                               4000 non-null   object
#  4   past_3_years_bike_related_purchases  4000 non-null   int64
#  5   DOB                                  3913 non-null   datetime64[ns]
#  6   job_title                            3494 non-null   object
#  7   job_industry_category                3344 non-null   object
#  8   wealth_segment                       4000 non-null   object
#  9   deceased_indicator                   4000 non-null   object
#  10  owns_car                             4000 non-null   object
# ...

# %%
customermerger_df = pd.merge(customerdemographic_df, customeraddress_df, how ='left', on ='customer_id')

# %%
customermerger_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4000 entries, 0 to 3999
# Data columns (total 17 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   customer_id                          4000 non-null   int64
#  1   first_name                           4000 non-null   object
#  2   last_name                            3875 non-null   object
#  3   gender                               4000 non-null   object
#  4   past_3_years_bike_related_purchases  4000 non-null   int64
#  5   DOB                                  3913 non-null   datetime64[ns]
#  6   job_title                            3494 non-null   object
#  7   job_industry_category                3344 non-null   object
#  8   wealth_segment                       4000 non-null   object
#  9   deceased_indicator                   4000 non-null   object
#  10  owns_car                             4000 non-null   object
# ...

# %%
customermerger_df['postcode'] = customermerger_df['postcode']. fillna(method = 'ffill')
customermerger_df.head()
# Out:
#    customer_id first_name last_name  gender  \
# 0          720     Darrel     Canet    Male
# 1         1092     Katlin   Creddon  Female
# 2         3410    Merrili   Brittin  Female
# 3         2413      Abbey    Murrow    Male
# 4          658       Donn   Bonnell    Male
#
#    past_3_years_bike_related_purchases        DOB                 job_title  \
# 0                                   67 1931-10-23        Recruiting Manager
# 1                                   56 1935-08-22        VP Quality Control
# 2                                   93 1940-09-22                       NaN
# 3                                   27 1943-08-11  Environmental Specialist
# 4                                   38 1944-01-24            Tax Accountant
#
#   job_industry_category     wealth_segment deceased_indicator owns_car  \
# 0                Retail  Affluent Customer                  N       No
# 1                Retail      Mass Customer                  N       No
# ...

# %%
 customermerge_df =pd.merge(customermerger_df,trans_df, how = 'left', on='customer_id' )

# %%
customermerge_df.head()
# Out:
#    customer_id first_name last_name gender  \
# 0          720     Darrel     Canet   Male
# 1          720     Darrel     Canet   Male
# 2          720     Darrel     Canet   Male
# 3          720     Darrel     Canet   Male
# 4          720     Darrel     Canet   Male
#
#    past_3_years_bike_related_purchases        DOB           job_title  \
# 0                                   67 1931-10-23  Recruiting Manager
# 1                                   67 1931-10-23  Recruiting Manager
# 2                                   67 1931-10-23  Recruiting Manager
# 3                                   67 1931-10-23  Recruiting Manager
# 4                                   67 1931-10-23  Recruiting Manager
#
#   job_industry_category     wealth_segment deceased_indicator  ...  \
# 0                Retail  Affluent Customer                  N  ...
# 1                Retail  Affluent Customer                  N  ...
# 2                Retail  Affluent Customer                  N  ...
# ...

# %%
customermerge_df['DOB'] = customermerge_df['DOB'].fillna(method = 'ffill')
customermerge_df['postcode'] = customermerge_df['postcode'].fillna(method = 'ffill')
customermerge_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20504 entries, 0 to 20503
# Data columns (total 29 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   customer_id                          20504 non-null  int64
#  1   first_name                           20504 non-null  object
#  2   last_name                            19849 non-null  object
#  3   gender                               20504 non-null  object
#  4   past_3_years_bike_related_purchases  20504 non-null  int64
#  5   DOB                                  20504 non-null  datetime64[ns]
#  6   job_title                            18027 non-null  object
#  7   job_industry_category                17180 non-null  object
#  8   wealth_segment                       20504 non-null  object
#  9   deceased_indicator                   20504 non-null  object
#  10  owns_car                             20504 non-null  object
# ...

# %%
customermerge_df['DOB'] = pd.to_datetime(customermerge_df['DOB'],errors = 'coerce')
now = pd.to_datetime('now')
customermerge_df['age'] =  (now.year - customermerge_df['DOB'].dt.year) - ((now.month - customermerge_df['DOB'].dt.month) < 0)
customermerge_df['age']
# Out:
# 0         88
# 1         88
# 2         88
# 3         88
# 4         88
#         ...
# 20499    176
# 20500    176
# 20501    176
# 20502    176
# 20503    176
# Name: age, Length: 20504, dtype: int64

# %%
customermerge_df = customermerge_df.drop('DOB', axis=1)

customermerge_df['postcode'] = customermerge_df['postcode'].fillna(method = 'ffill')

# %%
customermerge_df = customermerge_df.astype({'postcode':int})

# %%
customermerge_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20504 entries, 0 to 20503
# Data columns (total 29 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   customer_id                          20504 non-null  int64
#  1   first_name                           20504 non-null  object
#  2   last_name                            19849 non-null  object
#  3   gender                               20504 non-null  object
#  4   past_3_years_bike_related_purchases  20504 non-null  int64
#  5   job_title                            18027 non-null  object
#  6   job_industry_category                17180 non-null  object
#  7   wealth_segment                       20504 non-null  object
#  8   deceased_indicator                   20504 non-null  object
#  9   owns_car                             20504 non-null  object
#  10  tenure                               20047 non-null  float64
# ...

# %%
newcustomerlist_df = newcustomerlist_df.astype({'postcode': int})
newcustomerlist_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 18 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   first_name                           1000 non-null   object
#  1   last_name                            971 non-null    object
#  2   gender                               1000 non-null   object
#  3   past_3_years_bike_related_purchases  1000 non-null   int64
#  4   DOB                                  1000 non-null   datetime64[ns]
#  5   job_title                            1000 non-null   object
#  6   job_industry_category                1000 non-null   object
#  7   wealth_segment                       1000 non-null   object
#  8   deceased_indicator                   1000 non-null   object
#  9   owns_car                             1000 non-null   object
#  10  tenure                               1000 non-null   float64
# ...

# %%
newcustomerlist_df['DOB'] = pd.to_datetime(newcustomerlist_df['DOB'],errors='coerce')
now = pd.to_datetime('now')

# %%
newcustomerlist_df['age'] = (now.year - newcustomerlist_df['DOB'].dt.year) - ((now.month - newcustomerlist_df['DOB'].dt.month) < 0)

newcustomerlist_df['age']
# Out:
# 0      62
# 1      50
# 2      45
# 3      41
# 4      54
#        ..
# 995    60
# 996    18
# 997    65
# 998    67
# 999    64
# Name: age, Length: 1000, dtype: int64

# %%
newcustomerlist_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 19 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   first_name                           1000 non-null   object
#  1   last_name                            971 non-null    object
#  2   gender                               1000 non-null   object
#  3   past_3_years_bike_related_purchases  1000 non-null   int64
#  4   DOB                                  1000 non-null   datetime64[ns]
#  5   job_title                            1000 non-null   object
#  6   job_industry_category                1000 non-null   object
#  7   wealth_segment                       1000 non-null   object
#  8   deceased_indicator                   1000 non-null   object
#  9   owns_car                             1000 non-null   object
#  10  tenure                               1000 non-null   float64
# ...

# %%
newcustomerlist_df.head()
# Out:
#   first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0    Chickie    Brister    Male                                   86
# 1      Morly     Genery    Male                                   69
# 2    Ardelis  Forrester  Female                                   10
# 3     Lucine      Stutt  Female                                   64
# 4    Melinda     Hadlee  Female                                   34
#
#          DOB                   job_title job_industry_category  \
# 0 1957-07-12             General Manager         Manufacturing
# 1 1970-03-22         Structural Engineer              Property
# 2 1974-08-28      Senior Cost Accountant    Financial Services
# 3 1979-01-28  Account Representative III         Manufacturing
# 4 1965-09-21           Financial Analyst    Financial Services
#
#       wealth_segment deceased_indicator owns_car  tenure              address  \
# 0      Mass Customer                  N      Yes    14.0     45 Shopko Center
# ...

# %%
newcustomerlist_df.drop('DOB',axis = 1)
# Out:
#     first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0      Chickie    Brister    Male                                   86
# 1        Morly     Genery    Male                                   69
# 2      Ardelis  Forrester  Female                                   10
# 3       Lucine      Stutt  Female                                   64
# 4      Melinda     Hadlee  Female                                   34
# ..         ...        ...     ...                                  ...
# 995  Ferdinand  Romanetti    Male                                   60
# 996       Burk    Wortley    Male                                   22
# 997   Melloney      Temby  Female                                   17
# 998     Dickie    Cubbini    Male                                   30
# 999      Sylas    Duffill    Male                                   56
#
#                         job_title job_industry_category     wealth_segment  \
# ...

# %%
newcustomerlist_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 19 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   first_name                           1000 non-null   object
#  1   last_name                            971 non-null    object
#  2   gender                               1000 non-null   object
#  3   past_3_years_bike_related_purchases  1000 non-null   int64
#  4   DOB                                  1000 non-null   datetime64[ns]
#  5   job_title                            1000 non-null   object
#  6   job_industry_category                1000 non-null   object
#  7   wealth_segment                       1000 non-null   object
#  8   deceased_indicator                   1000 non-null   object
#  9   owns_car                             1000 non-null   object
#  10  tenure                               1000 non-null   float64
# ...

# %%
customermerge_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20504 entries, 0 to 20503
# Data columns (total 29 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   customer_id                          20504 non-null  int64
#  1   first_name                           20504 non-null  object
#  2   last_name                            19849 non-null  object
#  3   gender                               20504 non-null  object
#  4   past_3_years_bike_related_purchases  20504 non-null  int64
#  5   job_title                            18027 non-null  object
#  6   job_industry_category                17180 non-null  object
#  7   wealth_segment                       20504 non-null  object
#  8   deceased_indicator                   20504 non-null  object
#  9   owns_car                             20504 non-null  object
#  10  tenure                               20047 non-null  float64
# ...
